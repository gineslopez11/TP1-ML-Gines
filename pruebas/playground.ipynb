# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dev = pd.read_csv("../data/casas_dev.csv")

# %% [markdown]
# FUNCIONES BASICAS PARA EXPLORAR DATASET

# %%
dev.head()

# %% [markdown]
# Primeras 5 (predeterminado) filas del dataset

# %%
dev.sample(5)

# %% [markdown]
# Filas aleatorias

# %%
dev.info()

# %% [markdown]
# Muestra:
# Nombres de las columnas
# Tipo de dato
# Cantidad de valores no nulos
#
# --> Sirve para detectar NaN y columnas con tipo incorrecto

# %%
dev.describe()

# %% [markdown]
# Estadisticas de las columnas numericas
#
# --> Detectar valores raros/extremos

# %%
dev.isna().sum()

# %% [markdown]
# Cuantos valores faltantes hay en cada columna
